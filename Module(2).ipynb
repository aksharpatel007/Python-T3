# %%
#.py and .ipynb extension both available for accessing and importing module
import Module
#print(x) Gives error
print(Module.x)
Module.add(5,10)
Module.mul(5,10)

# %%
#imported module can also be accesses in other cells
print(Module.x)
Module.add(5,10)
Module.mul(5,10)

# %%
import Module as k
k.add(5,10)

# %%
from Module import x,add
print(x)
(add(5,10))

# %%
# %%writefile module3.py
x=500
def add(a,b):
    print("sum= "+(a+b))
def product(a,b):
    print("product= "+(a*b))
    #Only works in Jupyter

# %%
# %%writefile module3.py
x=700
def sub(a,b):
    print("sub= "+(a+b))

def div(a,b):
    print("div= "+(a/b))

# %%
import Module
Module.mul(8,9)

# %%
#OS Module
import os
os.getcwd()#Gives file path
os.mkdir("D:\meow")
#os.rmdir("D:\meow")
#os.remove("C:\Windows\System32\drivers")
os.chdir(r"D:\meow")

print(os.listdir("C:\Windows\System32"))

# %%
import sys
sys.version

# %%
sys.maxsize

# %%
sys.path

# %%
import datetime
print(datetime.datetime.now())

# %%
print(datetime.date.today)
datetime.date.today()

# %%
me=datetime.time(12,10,45)
print(me)
print(datetime.time(10,8,30))

# %%
now=datetime.datetime.now()
print(me.microsecond)
print(me.second)
print(me.minute)
print(me.hour)
print(now.year)
print(now.month)
print(now.day)
